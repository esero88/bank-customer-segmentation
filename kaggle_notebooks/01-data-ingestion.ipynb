# %%
import os

os.environ['KAGGLE_USERNAME'] = 'eserkaraceper'
os.environ['KAGGLE_KEY'] = 'KGAT_51b801211634399495b346aac1eac83e'

# %%
# !kaggle datasets download -d shivamb/bank-customer-segmentation
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/shivamb/bank-customer-segmentation
# License(s): copyright-authors
# ...
#   0%|          | 0.00/24.2M [00:00<?, ?B/s]
#   4%|4         | 1.00M/24.2M [00:00<00:18, 1.34MB/s]
#   8%|8         | 2.00M/24.2M [00:00<00:08, 2.70MB/s]
#  17%|#6        | 4.00M/24.2M [00:01<00:04, 5.25MB/s]
#  25%|##4       | 6.00M/24.2M [00:01<00:02, 7.07MB/s]
#  29%|##8       | 7.00M/24.2M [00:01<00:02, 7.70MB/s]
#  33%|###3      | 8.00M/24.2M [00:01<00:02, 8.20MB/s]
#  37%|###7      | 9.00M/24.2M [00:01<00:01, 8.27MB/s]
#  45%|####5     | 11.0M/24.2M [00:01<00:01, 9.90MB/s]
#  54%|#####3    | 13.0M/24.2M [00:01<00:01, 11.1MB/s]
#  62%|######2   | 15.0M/24.2M [00:02<00:00, 11.1MB/s]
#  70%|#######   | 17.0M/24.2M [00:02<00:00, 11.8MB/s]
#  79%|#######8  | 19.0M/24.2M [00:02<00:00, 12.0MB/s]
#  87%|########6 | 21.0M/24.2M [00:02<00:00, 11.2MB/s]
#  95%|#########5| 23.0M/24.2M [00:02<00:00, 11.2MB/s]
# 100%|##########| 24.2M/24.2M [00:02<00:00, 8.75MB/s]

# %%
import zipfile

with zipfile.ZipFile("../data/bank-customer-segmentation.zip", 'r') as zip_ref:
    zip_ref.extractall("../data")

# %%
import pandas as pd

df = pd.read_csv("../data/bank_transactions.csv")
df.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1            T2   C2142763      4/4/57          M      JHAJJAR
# 2            T3   C4417068    26/11/96          F       MUMBAI
# 3            T4   C5342380     14/9/73          F       MUMBAI
# 4            T5   C9031234     24/3/88          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05          2/8/16           143207
# 1             2270.69          2/8/16           141858
# 2            17874.44          2/8/16           142712
# 3           866503.21          2/8/16           142714
# 4             6714.43          2/8/16           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5
